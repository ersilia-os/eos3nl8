# %% [markdown]
# # Focusing on the drugs in the infer_drug.tsv file

# %% [markdown]
# ### Get the mapping of SMILES and DrugBankID

# %%
# read drugbank_smiles.txt
import numpy as np
import pandas as pd
import csv
from io import StringIO 
import torch as th

file_path = "../drugbank_info/drugbank_smiles.txt"

smiles_mapping = dict()

# Read the text file line by line and populate the dictionary
with open(file_path, 'r') as file:
    for line in file:
        # Split each line into DrugBankID and SMILES using tab as the delimiter
        drugbank_id, smiles = line.strip().split('\t')
        
        # Add the entry to the dictionary
        smiles_mapping[drugbank_id] = smiles

# Display the dictionaries
# print(smiles_mapping)

# %%
# Get the number of available drugs in the drug bank
len(smiles_mapping)
# Out:
# 8807

# %% [markdown]
# There are 8807 compounds in the `drugbank_smiles.txt` file.
#
# NOTE: Not all the drugs here are in the `infer_drug.tsv` file. E.g `DB14708, DB00114, DB00117, DB00119, DB00120, DB00121, ... `
# The `infer_drug.tsv` only has drugs with a molecular weight >= 250.

# %% [markdown]
# ## Get the embeddings of each SMILES

# %%
# Load entity file
entity_idmap_file = '../data/embed/entities.tsv'

# Get all the drugs on a list 
# drug_list = list(df['DrugBankID'])

# Load entity file
drug_list = []
with open("./infer_drug.tsv", newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile, delimiter='\t', fieldnames=['drug','ids'])
    for row_val in reader:
        drug_list.append(row_val['drug'])

print("There are", len(drug_list), "drugs in the infer_drug file")
# Out:
# There are 8104 drugs in the infer_drug file

# %%
# Get drug name to entity ID mappings
entity_map = {}

with open(entity_idmap_file, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile, delimiter='\t', fieldnames=['name','id'])
    for row_val in reader:
        entity_map[row_val['name']] = int(row_val['id'])
 
# handle the ID mapping
drug_ids = []
drug_entity = {}  # mapping for drugs to entity for drugs in the DRKG only 
# disease_ids = []
for drug in drug_list:
    drug_entity.update({drug:entity_map[drug]})
    drug_ids.append(entity_map[drug])

# %%
# preview the dictionary
print({k: drug_entity[k] for k in list(drug_entity)[:5]})

# get the length of the dictionary
print(len(drug_entity))
# Out:
# {'Compound::DB00605': 9475, 'Compound::DB00983': 11010, 'Compound::DB01240': 7486, 'Compound::DB11755': 16376, 'Compound::DB12184': 4505}
# 8104

# %% [markdown]
# There are 8104 drugs in the `drug_entity` mapping. All the drugs have been mapped.

# %%
# Create a dataframe of the drug_entity dictionary
df = pd.DataFrame(list(drug_entity.items()), 
                  columns=['drug_bank_id', 'entity_id'])
df['drug_bank_id'] = df['drug_bank_id'].str.replace('Compound::', '')
df.head()
# Out:
#   drug_bank_id  entity_id
# 0      DB00605       9475
# 1      DB00983      11010
# 2      DB01240       7486
# 3      DB11755      16376
# 4      DB12184       4505

# %%
# Adding the SMILES column based on the smiles_mapping dictionary
df['SMILES'] = df['drug_bank_id'].map(smiles_mapping)

# Handle NaN values and convert 'SMILES' column to integers and 
# df['SMILES'] = df['SMILES'].fillna(-1).astype(int)

df.head()
# Out:
#   drug_bank_id  entity_id                                             SMILES
# 0      DB00605       9475  CC1=C(CC(O)=O)C2=CC(F)=CC=C2\C1=C/C1=CC=C(C=C1...
# 1      DB00983      11010     COC1=CC=C(CC(C)NCC(O)C2=CC(NC=O)=C(O)C=C2)C=C1
# 2      DB01240       7486  [H][C@]12C[C@@H](O)[C@H](\C=C\[C@@H](O)CCCCC)[...
# 3      DB11755      16376   CCCC1=CC(O)=C2[C@@H]3C=C(C)CC[C@H]3C(C)(C)OC2=C1
# 4      DB12184       4505    CC1(C)CC(=O)N(CCCCN2CCN(CC2)C2=NC=CC=N2)C(=O)C1

# %%
# Check for missing values (NaN) in the 'SMILES' column
df[df['SMILES'].isna()]
# Out:
#      drug_bank_id  entity_id SMILES
# 14        DB12274      15567    NaN
# 15        DB13375      15614    NaN
# 27        DB05325      15694    NaN
# 38        DB00026      10157    NaN
# 51        DB01277      10394    NaN
# ...           ...        ...    ...
# 8077      DB14793       5019    NaN
# 8078      DB09108      24669    NaN
# 8082      DB12009      14702    NaN
# 8084      DB13900      25019    NaN
# 8093      DB11836      11419    NaN
#
# [1583 rows x 3 columns]

# %% [markdown]
# There are 1583 missing values of SMILES. We will filter them out.

# %%
df = df[df['SMILES'].notna()]
print(df.shape)
df.head()
# Out:
# (6521, 3)
#   drug_bank_id  entity_id                                             SMILES
# 0      DB00605       9475  CC1=C(CC(O)=O)C2=CC(F)=CC=C2\C1=C/C1=CC=C(C=C1...
# 1      DB00983      11010     COC1=CC=C(CC(C)NCC(O)C2=CC(NC=O)=C(O)C=C2)C=C1
# 2      DB01240       7486  [H][C@]12C[C@@H](O)[C@H](\C=C\[C@@H](O)CCCCC)[...
# 3      DB11755      16376   CCCC1=CC(O)=C2[C@@H]3C=C(C)CC[C@H]3C(C)(C)OC2=C1
# 4      DB12184       4505    CC1(C)CC(=O)N(CCCCN2CCN(CC2)C2=NC=CC=N2)C(=O)C1

# %%
df.tail()
# Out:
#      drug_bank_id  entity_id  \
# 8099      DB03445      22548
# 8100      DB11200      24747
# 8101      DB01897      21144
# 8102      DB08404      24473
# 8103      DB05455      23655
#
#                                                  SMILES
# 8099  [H]\C(N[C@@]([H])(C(O)=O)[C@](C)(CN1C=CN=N1)S(...
# 8100                O.O.[Al+3].[Cl-].[Zr+4].NCC([O-])=O
# 8101  O=C1NNC(=O)C2=CC(=CC=C12)[N+]1=NC(\C=C\C2=CC=C...
# 8102  [H][C@](O)(C(=O)NCCC(=O)NCCSC(=O)CCCCC)C(C)(C)...
# 8103  CCOC1=CC2=C(C=C1)N(C(=O)C23CCC(CC3)OCCN4CCOCC4...

# %% [markdown]
# There are `6521` drugs from the `infer_drugs` files that have a SMILES value from the `drugbank_smiles.txt` file.

# %%
drug_ids[:5]
# Out:
# [9475, 11010, 7486, 16376, 4505]

# %% [markdown]
# The `drug_ids` list values are in the same order as the `entity_id` column in our dataframe.
# It will be easy to concatenate the embedding of each drug to the dataframe based on the `entity_id.`

# %%
len(drug_ids)
# Out:
# 8104

# %% [markdown]
# The lenght of `drug_ids` is still `8104`. We need to remove the drug_ids that are not in our dataframe.

# %%
# Get only the drug_ids that are in the dataframe
drug_ids = [k for k in drug_ids if k in set(df['entity_id'])]

# check
print(len(drug_ids))
# Out:
# 6521

# %%
drug_ids[:10]
# Out:
# [9475, 11010, 7486, 16376, 4505, 7417, 6457, 7161, 2415, 4943]

# %% [markdown]
# Now the lenght of drug_ids match the lenght of the dataframe.

# %%
# Load embedding
entity_emb = np.load('../data/embed/DRKG_TransE_l2_entity.npy')

drug_ids = th.tensor(drug_ids).long()
drug_emb = th.tensor(entity_emb[drug_ids])

# %%
# view the entity embeddings
entity_emb
# Out:
# array([[-0.5888741 , -0.0872229 , -0.45159575, ...,  0.6187399 ,
#         -0.51274306,  0.43644685],
#        [ 0.03043327, -0.9927482 ,  0.31472597, ..., -0.03531377,
#         -0.7016256 , -0.07200253],
#        [-0.15260178, -0.31713626, -0.3052066 , ..., -0.5843045 ,
#         -0.5971722 ,  0.4716604 ],
#        ...,
#        [ 0.58301383,  0.69486225,  0.5986209 , ...,  0.58480304,
#          0.5156303 ,  0.27735808],
#        [ 0.7441235 , -0.58081806,  0.3950408 , ...,  0.56884754,
#         -0.6283229 ,  0.5594293 ],
#        [-0.6101573 , -0.4708205 , -0.4374642 , ...,  0.42074913,
#         -0.56538516,  0.621319  ]], dtype=float32)

# %%
# view only the drug embeddings, which is a subset of the entity embeddings
print(len(drug_emb))
drug_emb
# Out:
# 6521
# tensor([[-0.2715, -0.5940, -0.3701,  ..., -0.5073,  0.1592, -0.6702],
#         [-0.4294, -0.3552, -0.4526,  ...,  0.6304,  0.4417, -0.4394],
#         [-0.6724, -0.2223, -0.5301,  ...,  0.3787,  0.3645, -0.3003],
#         ...,
#         [ 0.1658,  0.6800, -0.5095,  ..., -0.6383, -0.5285, -0.6048],
#         [ 0.5265,  0.6320, -0.5831,  ...,  0.5215, -0.5397,  0.5052],
#         [-0.5288, -0.4380, -0.6211,  ..., -0.5878, -0.5739, -0.5481]])

# %%
# Convert the tensor to a Pandas DataFrame
emb_df = pd.DataFrame(drug_emb.numpy(), columns=[f'embedding_{i}' for i in range(400)])

# Concatenate the new DataFrame with the existing DataFrame
result_df = pd.concat([df.reset_index(drop=True), emb_df], axis=1)

# Display the updated DataFrame
result_df.head(10)
# Out:
#   drug_bank_id  entity_id                                             SMILES  \
# 0      DB00605       9475  CC1=C(CC(O)=O)C2=CC(F)=CC=C2\C1=C/C1=CC=C(C=C1...
# 1      DB00983      11010     COC1=CC=C(CC(C)NCC(O)C2=CC(NC=O)=C(O)C=C2)C=C1
# 2      DB01240       7486  [H][C@]12C[C@@H](O)[C@H](\C=C\[C@@H](O)CCCCC)[...
# 3      DB11755      16376   CCCC1=CC(O)=C2[C@@H]3C=C(C)CC[C@H]3C(C)(C)OC2=C1
# 4      DB12184       4505    CC1(C)CC(=O)N(CCCCN2CCN(CC2)C2=NC=CC=N2)C(=O)C1
# 5      DB00404       7417     CC1=NN=C2CN=C(C3=CC=CC=C3)C3=C(C=CC(Cl)=C3)N12
# 6      DB01223       6457  NCCN.CN1C2=C(NC=N2)C(=O)N(C)C1=O.CN1C2=C(NC=N2...
# 7      DB00572       7161  CN1[C@H]2CC[C@@H]1C[C@@H](C2)OC(=O)C(CO)C1=CC=...
# 8      DB00669       2415             CNS(=O)(=O)CC1=CC2=C(NC=C2CCN(C)C)C=C1
# 9      DB00494       4943  CCN(CC)C(=O)C(=C\C1=CC(=C(O)C(O)=C1)[N+]([O-])...
#
#    embedding_0  embedding_1  embedding_2  embedding_3  embedding_4  \
# 0    -0.271492    -0.593986    -0.370118    -0.132015     0.647420
# 1    -0.429383    -0.355152    -0.452635    -0.493196    -0.350862
# 2    -0.672433    -0.222313    -0.530109    -0.546897     0.308746
# 3    -0.369791     0.667106    -0.406856    -0.587619     0.577712
# 4    -0.151366     0.479758    -0.379089    -0.545514     0.743205
# 5    -0.589351    -0.580602    -0.745123    -0.528509     0.593207
# 6    -0.674336    -0.266500    -0.512340    -0.115845    -0.309642
# 7    -0.297685    -0.514792    -0.603773    -0.658746     0.420709
# 8    -0.453169    -0.235891    -0.643428    -0.610339     0.023665
# 9    -0.535264    -0.502035    -0.528655    -0.100440    -0.082784
#
#    embedding_5  embedding_6  ...  embedding_390  embedding_391  embedding_392  \
# 0     0.267383     0.221824  ...      -0.110515       0.747298      -0.595123
# 1     0.713262     0.443782  ...      -0.542713       0.260568      -0.455372
# 2    -0.337016     0.149878  ...       0.565954      -0.691679      -0.595132
# 3     0.643965    -0.662907  ...       0.459833      -0.737107      -0.616846
# 4     0.751715    -0.588066  ...       0.427640      -0.665244      -0.284450
# 5     0.497097     0.048647  ...      -0.678077      -0.345387      -0.128594
# 6     0.626041     0.451178  ...      -0.554611       0.078451      -0.180794
# 7     0.737039     0.000725  ...      -0.306882       0.153852      -0.428181
# 8    -0.006115    -0.559450  ...       0.119811       0.474479       0.602419
# 9     0.540049     0.041261  ...      -0.705202       0.230018      -0.369495
#
#    embedding_393  embedding_394  embedding_395  embedding_396  embedding_397  \
# 0      -0.354849       0.426570      -0.651937      -0.535123      -0.507326
# 1      -0.012449      -0.440367      -0.572628      -0.547223       0.630401
# 2      -0.309585       0.082130      -0.466184      -0.515885       0.378655
# 3      -0.169433      -0.602083      -0.120658      -0.194525      -0.377465
# 4       0.689696      -0.577339      -0.528556       0.713676      -0.300458
# 5       0.402087       0.085832      -0.420954      -0.311380      -0.376174
# 6      -0.402600      -0.749248       0.438113      -0.795475      -0.051928
# 7      -0.233794      -0.307042      -0.313246      -0.309900       0.096056
# 8       0.255796      -0.105829      -0.557198       0.094172       0.142557
# 9       0.308531       0.017748      -0.620017       0.475681       0.461897
#
#    embedding_398  embedding_399
# 0       0.159212      -0.670219
# 1       0.441735      -0.439394
# 2       0.364504      -0.300323
# 3       0.231654      -0.369904
# 4       0.254337       0.029720
# 5       0.388722      -0.459413
# 6       0.437143      -0.286584
# 7       0.473331      -0.490021
# 8       0.284198      -0.518554
# 9       0.462243      -0.646051
#
# [10 rows x 403 columns]

# %%
emb_df.shape
# Out:
# (6521, 400)

# %%
# Now remove the entity_id column
result_df.drop('entity_id', inplace=True, axis=1)
result_df.head()
# Out:
#   drug_bank_id                                             SMILES  \
# 0      DB00605  CC1=C(CC(O)=O)C2=CC(F)=CC=C2\C1=C/C1=CC=C(C=C1...
# 1      DB00983     COC1=CC=C(CC(C)NCC(O)C2=CC(NC=O)=C(O)C=C2)C=C1
# 2      DB01240  [H][C@]12C[C@@H](O)[C@H](\C=C\[C@@H](O)CCCCC)[...
# 3      DB11755   CCCC1=CC(O)=C2[C@@H]3C=C(C)CC[C@H]3C(C)(C)OC2=C1
# 4      DB12184    CC1(C)CC(=O)N(CCCCN2CCN(CC2)C2=NC=CC=N2)C(=O)C1
#
#    embedding_0  embedding_1  embedding_2  embedding_3  embedding_4  \
# 0    -0.271492    -0.593986    -0.370118    -0.132015     0.647420
# 1    -0.429383    -0.355152    -0.452635    -0.493196    -0.350862
# 2    -0.672433    -0.222313    -0.530109    -0.546897     0.308746
# 3    -0.369791     0.667106    -0.406856    -0.587619     0.577712
# 4    -0.151366     0.479758    -0.379089    -0.545514     0.743205
#
#    embedding_5  embedding_6  embedding_7  ...  embedding_390  embedding_391  \
# 0     0.267383     0.221824    -0.669338  ...      -0.110515       0.747298
# 1     0.713262     0.443782    -0.526725  ...      -0.542713       0.260568
# 2    -0.337016     0.149878    -0.787017  ...       0.565954      -0.691679
# 3     0.643965    -0.662907    -0.538321  ...       0.459833      -0.737107
# 4     0.751715    -0.588066    -0.573652  ...       0.427640      -0.665244
#
#    embedding_392  embedding_393  embedding_394  embedding_395  embedding_396  \
# 0      -0.595123      -0.354849       0.426570      -0.651937      -0.535123
# 1      -0.455372      -0.012449      -0.440367      -0.572628      -0.547223
# 2      -0.595132      -0.309585       0.082130      -0.466184      -0.515885
# 3      -0.616846      -0.169433      -0.602083      -0.120658      -0.194525
# 4      -0.284450       0.689696      -0.577339      -0.528556       0.713676
#
#    embedding_397  embedding_398  embedding_399
# 0      -0.507326       0.159212      -0.670219
# 1       0.630401       0.441735      -0.439394
# 2       0.378655       0.364504      -0.300323
# 3      -0.377465       0.231654      -0.369904
# 4      -0.300458       0.254337       0.029720
#
# [5 rows x 402 columns]

# %%
result_df.tail(50)
# Out:
#      drug_bank_id                                             SMILES  \
# 6471      DB03064                        CCCCCCCCCCC1=C(O)C(=O)NC1=O
# 6472      DB03495  [H][C@]1(C)O[C@]([H])(O[C@]2([H])[C@@]([H])(CO...
# 6473      DB02449  [H][C@@](CC1=CNC2=CC=CC=C12)(NS(=O)(=O)C1=CC=C...
# 6474      DB04000                N[C@@H](CN1C=C(Br)C(=O)NC1=O)C(O)=O
# 6475      DB06988  [H][C@](N)(CC1=CC(\N=C\CC2=CC=CC=C2)=C(O)C=C1O...
# 6504      DB07839  [H][C@@](CC1CCCCC1)(NC1=NC2=CC=CC=C2O1)C(=O)NC...
# 6505      DB04701      CSC[C@H](NC(=O)CC[C@H](N)C(O)=O)C(=O)NCC(O)=O
# 6506      DB07604  [H][C@@]12CC3=C4C(NC=C4[C@]1([H])[C@]1([H])N(C...
# 6507      DB01773  CN(CCCC1CCCCC1)C(=O)[C@H](CCC(O)=O)NC(=O)N(CC(...
# 6508      DB08419           [H][C@](CC)(COC1=CC=CC=C1)O[P@](C)(Cl)=O
# 6509      DB08485  [H][C@@]1(O)C[C@@](O)(C=C(C2=CC=CC(SC3=CC=CC=C...
# 6510      DB07262                NC(=N)NC(=N)SCC1=CC=CC(=C1)C(F)(F)F
# 6511      DB07030  OC(=O)COC1=CC(Cl)=CC=C1C(=O)NCC1=CC(=CC=C1)[N+...
# 6512      DB05364  C1CN2C(=CC=C2C(=O)C3=CC=CC=C3)C1C(=O)O.C(C(CO)...
# 6513      DB04746                       CCCCC\C=C/C=C/CCCCCCCCC(O)=O
# 6514      DB01703  N1(C(=O)C=CC1=O)CCC12[Fe]3456789%10C%11C3C4C5C...
# 6515      DB07521  [H][C@]1(CC\N=C2/NC[C@]([H])(Cl)N(CCNCC3=CSC4=...
# 6516      DB03445  [H]\C(N[C@@]([H])(C(O)=O)[C@](C)(CN1C=CN=N1)S(...
# 6517      DB11200                O.O.[Al+3].[Cl-].[Zr+4].NCC([O-])=O
# 6518      DB01897  O=C1NNC(=O)C2=CC(=CC=C12)[N+]1=NC(\C=C\C2=CC=C...
# 6519      DB08404  [H][C@](O)(C(=O)NCCC(=O)NCCSC(=O)CCCCC)C(C)(C)...
# 6520      DB05455  CCOC1=CC2=C(C=C1)N(C(=O)C23CCC(CC3)OCCN4CCOCC4...
#
#       embedding_0  embedding_1  embedding_2  embedding_3  embedding_4  \
# 6471    -0.472310     0.647877    -0.089998     0.637965     0.650257
# 6472     0.526832     0.587521    -0.611328     0.652814     0.554662
# 6473     0.638514     0.666598    -0.514444     0.568460     0.529452
# 6474     0.583121     0.659789    -0.581984     0.583822    -0.450307
# 6475     0.541772     0.641629    -0.622913     0.551972     0.653459
# 6476     0.562265     0.578854    -0.610164     0.554512    -0.433615
# 6477     0.529424     0.653089     0.457046    -0.590788     0.656969
# 6478    -0.393805     0.548372    -0.611566     0.530904     0.550117
# 6479    -0.410484     0.558169    -0.580630    -0.541515    -0.461676
# 6480    -0.602227     0.560188    -0.525971     0.565391     0.609303
# 6481     0.595611     0.644988    -0.650109     0.354257     0.653492
# 6482     0.408925     0.581882    -0.581374     0.589574    -0.504035
# 6483     0.513979     0.521212     0.357641     0.427821     0.612926
# 6484     0.558635    -0.418410    -0.623008     0.387692    -0.314126
# 6485     0.575564     0.604186    -0.591212    -0.581304     0.628970
# 6486     0.609232     0.645773     0.530845     0.585523     0.520658
# 6487     0.560216     0.635948    -0.603068    -0.559610     0.618254
# 6485    -0.458922    -0.562798     0.504306  ...      -0.617658
# 6486    -0.595922    -0.662190    -0.594004  ...      -0.471428
# 6487    -0.570203    -0.579497    -0.461914  ...      -0.598170
# 6488    -0.562579    -0.526854     0.368007  ...       0.542852
# 6489    -0.429627    -0.532822    -0.443852  ...       0.502401
# 6490    -0.462687    -0.546257     0.592144  ...      -0.586747
# 6491    -0.648314    -0.647620    -0.688168  ...       0.064016
# 6492    -0.486382    -0.547774     0.612721  ...      -0.473835
# 6493     0.660654    -0.531474     0.594969  ...      -0.452464
# 6494    -0.683831    -0.708033     0.677379  ...      -0.458650
# 6495    -0.580654    -0.532528    -0.450431  ...       0.453032
# 6496    -0.540685    -0.588664     0.619334  ...       0.563528
# 6497    -0.675868    -0.621204    -0.437650  ...      -0.429114
# 6498    -0.320402    -0.634656     0.652348  ...      -0.499580
# 6499    -0.608915    -0.618611    -0.498624  ...       0.489474
# 6500     0.510784    -0.635107     0.589719  ...      -0.595577
# 6501     0.580359    -0.603436     0.567497  ...      -0.562396
# 6502     0.456471    -0.614683     0.654173  ...      -0.638654
# 6503     0.572338     0.315611     0.608231  ...      -0.386161
# 6504    -0.497319     0.468750     0.596361  ...      -0.469318
# 6505     0.545894     0.461313    -0.474152  ...      -0.516053
# 6506    -0.626332     0.273202     0.528055  ...      -0.519102
# 6507     0.519968    -0.619820     0.465309  ...      -0.602146
# 6508     0.541142    -0.588551     0.508689  ...      -0.471057
# 6509    -0.576131    -0.596865     0.618197  ...      -0.587817
# 6510    -0.613027    -0.640013    -0.475835  ...      -0.452453
# 6511     0.540502    -0.588619     0.633370  ...      -0.565258
# 6512    -0.575896    -0.411542    -0.509424  ...      -0.527726
# 6513     0.522486    -0.613820    -0.470039  ...      -0.569111
# 6514    -0.371379    -0.451634     0.420210  ...      -0.617553
# 6515    -0.651763    -0.540291    -0.567808  ...      -0.481663
# 6516    -0.521052    -0.559005     0.521280  ...      -0.474528
# 6517    -0.550973    -0.575529     0.612341  ...      -0.557052
# 6518    -0.439071    -0.463242     0.415044  ...       0.514475
# 6519    -0.579116    -0.572851    -0.507023  ...      -0.597719
# 6520     0.417064    -0.686367    -0.363107  ...      -0.683306
#
#       embedding_391  embedding_392  embedding_393  embedding_394  \
# 6471      -0.593166       0.573260       0.626603       0.655367
# 6472      -0.396637       0.628750      -0.631339      -0.385175
# 6473      -0.570388       0.548918      -0.564680       0.569350
# 6474      -0.683417       0.464978       0.548842      -0.465284
# 6475       0.492067       0.591650       0.580336       0.614850
# 6476      -0.561762      -0.259173       0.553508       0.611597
# 6477       0.519024       0.553192      -0.606682       0.470672
# 6478       0.526975       0.544634      -0.581113       0.613318
# 6479       0.402756       0.579265      -0.538386       0.606561
# 6480      -0.562198       0.140094       0.346223       0.536255
# 6481       0.490548       0.610283       0.582584       0.644737
# 6482       0.405392       0.586531      -0.599398       0.518342
# 6483      -0.458551       0.596257       0.539860       0.609492
# 6484       0.491811       0.603537       0.492975       0.605668
# 6490       0.539979      -0.474226       0.590256      -0.559185
# 6491       0.558248      -0.696910      -0.434698       0.498668
# 6492      -0.560509       0.531693      -0.638646      -0.610379
# 6493      -0.609169       0.562374       0.277828       0.481350
# 6494      -0.624277      -0.545686       0.479742       0.534001
# 6495       0.478089      -0.482855       0.569772      -0.503266
# 6496      -0.311830       0.510627       0.548409       0.527843
# 6497      -0.529779      -0.447060       0.585127       0.586104
# 6498       0.591451      -0.484228      -0.578899      -0.305973
# 6499       0.550528      -0.590599       0.587875       0.492443
# 6500       0.590555      -0.587670      -0.412974      -0.551792
# 6501      -0.628179       0.499231      -0.634804       0.510483
# 6502      -0.319124      -0.495904       0.480373       0.449212
# 6503      -0.435052      -0.585984       0.505407       0.574568
# 6504      -0.601299       0.448998       0.233519       0.478091
# 6505      -0.355116      -0.626946      -0.537125       0.420354
# 6506      -0.484926      -0.679890      -0.476952       0.572170
# 6507       0.537643      -0.486118       0.509763      -0.549115
# 6508       0.610044       0.545314       0.535734      -0.463212
# 6509      -0.592968      -0.599744       0.507418       0.474016
# 6510       0.555718       0.471684       0.581960       0.442034
# 6511      -0.560185       0.518452      -0.607351       0.373176
# 6512       0.617545       0.600090       0.588658       0.592873
# 6513       0.565712       0.507718       0.520520       0.394691
# 6514       0.605862       0.273022       0.368200       0.603526
# 6515      -0.687364      -0.608776      -0.615371       0.396692
# 6516       0.619256      -0.439607       0.588916       0.446861
# 6517       0.554450      -0.587749      -0.466751      -0.539963
# 6518      -0.503990      -0.488678      -0.638342      -0.528476
# 6519       0.571994      -0.238655       0.521515      -0.539698
# 6520       0.517944      -0.616122      -0.587826      -0.573913
#
#       embedding_399
# 6471       0.508143
# 6472       0.443134
# 6473      -0.612271
# 6474      -0.448048
# 6475       0.449482
# 6476       0.493747
# 6477       0.462418
# 6478      -0.438014
# 6479      -0.623237
# 6480       0.578092
# 6481       0.523590
# 6482      -0.580581
# 6483       0.508804
# 6484       0.500475
# 6485       0.522771
# 6486      -0.607174
# 6487       0.520098
# 6488       0.292319
# 6489      -0.452717
# 6490       0.551875
# 6491       0.403329
# 6492      -0.373093
# 6493       0.438413
# 6494      -0.615644
# 6495       0.515584
# 6496       0.512945
# 6497      -0.601419
# 6498       0.514110
# 6499       0.550593
# 6500       0.538644
# 6501       0.492823
# 6502       0.550399
# 6503       0.526412
# 6504      -0.510844
# 6505      -0.611874
# 6506       0.430495
# 6507       0.481288
# 6508       0.537067
# 6509       0.441982
# 6510       0.496643
# 6511      -0.509822
# 6512      -0.569137
# 6513       0.512057
# 6514       0.506995
# 6515       0.519125
# 6516      -0.445121
# 6517       0.478317
# 6518      -0.604817
# 6519       0.505169
# 6520      -0.548133
#
# [50 rows x 402 columns]

# %%
result_df.shape
# Out:
# (6521, 402)

# %% [markdown]
# The shape show that there are 6521 rows. There are no missing values, but let's be sure.

# %%
# check for missing values
result_df.isna().sum().sum()
# Out:
# 0

# %%
# save to a CSV file
result_df.to_csv("smiles_embeddings_infer_drugs.csv")
